# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA) - PROJECT

# %% [markdown]
# #
# Dataset Description
# Literacy Rates Overview  1991,2001 and 2011 Dataset of india.
#
# This compiled dataset pulled has been taken from KAGGLE .It tells us the literacy rates of india and all its states and union territories.
# here we compare the literacy rates of male,female and total persons of year 1991 and 2001.we have also compare lieracy rates of rural and
# urban male,female & persons of the year 2011.
#
# Dataset Feature List -
#
# It shows the litercy rates for the country india of all the states of the
# year 1991,2001 and 2011 male and female total urban and rural %.
#
# . country
# . states
# . years
# . 1991-male and female %
# . 1991-total population %
# . 2001-male and female
# . 2011-male and female rural %
# . 2011- total rural population %
# . 2011-male and female urban %
# . 2011-total urban population%

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ecom=pd.read_excel(r"\Users\KUNAL\Desktop\PROJECT\literacyrate.xls")
ecom #read excel file
# Out:
#                states  Male_ninetyone  Female_ninetyone  Persons_ninetyone  \
# 0           All India              52                64                 39
# 1      Andhra Pradesh              44                55                 33
# 2   Arunachal Pradesh              42                52                 30
# 3               Assam              53                62                 43
# 4               Bihar              38                51                 22
# 5         Chhatisgarh              43                58                 28
# 6                 Goa              76                84                 67
# 7             Gujarat              61                73                 49
# 8             Haryana              56                69                 41
# 9    Himachal Pradesh              64                75                 52
# 10  Jammu and Kashmir               0                 0                  0
# ...

# %%
#show data first 5 rows
ecom.head()
# Out:
#               states  Male_ninetyone  Female_ninetyone  Persons_ninetyone  \
# 0          All India              52                64                 39
# 1     Andhra Pradesh              44                55                 33
# 2  Arunachal Pradesh              42                52                 30
# 3              Assam              53                62                 43
# 4              Bihar              38                51                 22
#
#    Male_zeroone  Female_zeroone  Persons_zeroone  RuralMale_twentyeleven  \
# 0            65              75               54                      77
# 1            61              70               50                      69
# 2            54              64               44                      67
# 3            63              71               55                      75
# 4            47              60               33                      70
#
#    RuralFemale_twentyeleven  RuralPerson_twentyeleven  UrbanMale_twentyeleven  \
# ...

# %%
#show data last 5 rows
ecom.tail()
# Out:
#               states  1991 - Male  1991 - Female  1991 - Persons  2001 - Male  \
# 31  D. and N. Haveli           41             54              27           58
# 32     Daman and Diu           71             83              59           78
# 33             Delhi           75             82              67           82
# 34       Lakshadweep           82             90              73           87
# 35        Puducherry           75             84              66           81
#
#     2001 - Female  2001 - Persons  2011 - Rural - Male  2011 - Rural - Female  \
# 31             71              40                   76                     50
# 32             87              66                   89                     72
# 33             87              75                   89                     73
# 34             93              81                   95                     89
# 35             89              74                   87                     73
#
# ...

# %%
#Describe function includes analysis of all our numerical data. For this, count, mean, std, min,% 25,% 50,% 75, max values are given.
ecom.describe()
# Out:
#        1991 - Male  1991 - Female  1991 - Persons  2001 - Male  2001 - Female  \
# count    36.000000      36.000000       36.000000    36.000000      36.000000
# mean     57.166667      67.222222       46.222222    69.583333      78.194444
# std      16.954561      16.442299       18.550489    10.645925       8.618318
# min       0.000000       0.000000        0.000000    47.000000      60.000000
# 25%      44.750000      57.500000       32.250000    63.000000      71.000000
# 50%      58.000000      68.000000       47.000000    69.000000      77.000000
# 75%      66.500000      77.500000       56.000000    77.250000      86.000000
# max      90.000000      94.000000       86.000000    91.000000      94.000000
#
#        2001 - Persons  2011 - Rural - Male  2011 - Rural - Female  \
# count       36.000000            36.000000              36.000000
# mean        59.861111            81.250000              65.416667
# std         13.556554             7.369338              11.738520
# ...

# %%
#The info function shows the data types and numerical values of the features in our data set.
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 15 columns):
# states               36 non-null object
# 1991_Male            36 non-null int64
# 1991_Female          36 non-null int64
# 1991_Persons         36 non-null int64
# 2001_Male            36 non-null int64
# 2001_Female          36 non-null int64
# 2001_Persons         36 non-null int64
# 2011_RuralMale       36 non-null int64
# 2011_RuralFemale     36 non-null int64
# 2011_RuralPerson     36 non-null int64
# 2011_UrbanMale       36 non-null int64
# 2011_UrbanFemale     36 non-null int64
# 2011_UrbanPersons    36 non-null int64
# Average_litrate      36 non-null float64
# level                36 non-null object
# dtypes: float64(1), int64(12), object(2)
# memory usage: 4.3+ KB

# %%
#We will now set the headings of the feature values in the data set.
ecom.columns
# Out:
# Index(['states', '1991_Male', '1991_Female', '1991_Persons', '2001_Male',
#        '2001_Female', '2001_Persons', '2011_RuralMale', '2011_RuralFemale',
#        '2011_RuralPerson', '2011_UrbanMale', '2011_UrbanFemale',
#        '2011_UrbanPersons', 'Average_litrate', 'level'],
#       dtype='object')

# %%
# how many rows and columns are there for all data?
print('Data Shape :')
ecom.shape
# Out:
# Data Shape :
# (36, 15)

# %%
# to check if there is any null data or not
ecom.isnull().any()
# Out:
# states               False
# 1991_Male            False
# 1991_Female          False
# 1991_Persons         False
# 2001_Male            False
# 2001_Female          False
# 2001_Persons         False
# 2011_RuralMale       False
# 2011_RuralFemale     False
# 2011_RuralPerson     False
# 2011_UrbanMale       False
# 2011_UrbanFemale     False
# 2011_UrbanPersons    False
# Average_litrate      False
# level                False
# dtype: bool

# %%
#Now,I will check null on all data and If data has null, I will sum of null data's. In this way, how many missing data is in the data.
ecom.isnull().sum()
# Out:
# states               0
# 1991_Male            0
# 1991_Female          0
# 1991_Persons         0
# 2001_Male            0
# 2001_Female          0
# 2001_Persons         0
# 2011_RuralMale       0
# 2011_RuralFemale     0
# 2011_RuralPerson     0
# 2011_UrbanMale       0
# 2011_UrbanFemale     0
# 2011_UrbanPersons    0
# Average_litrate      0
# level                0
# dtype: int64

# %%
# since there is no null value corresponding to the columns. Hence we will not delete any column
sns.heatmap(ecom.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
# 1.) How many total no of states are there for whom we are calculating literacy rates and also calculate how many loe there.w &high level literacy rates ar
ecom.states.value_counts().sort_index()
# Out:
# A. and N. Islands    1
# All India            1
# Andhra Pradesh       1
# Arunachal Pradesh    1
# Assam                1
# Bihar                1
# Chandigarh           1
# Chhatisgarh          1
# D. and N. Haveli     1
# Daman and Diu        1
# Delhi                1
# Goa                  1
# Gujarat              1
# Haryana              1
# Himachal Pradesh     1
# Jammu and Kashmir    1
# Jharkhand            1
# Karnataka            1
# Kerala               1
# Lakshadweep          1
# Madhya Pradesh       1
# Maharashtra          1
# Manipur              1
# Meghalaya            1
# Mizoram              1
# Nagaland             1
# Odisha               1
# Puducherry           1
# Punjab               1
# Rajasthan            1
# Sikkim               1
# Tamil Nadu           1
# Tripura              1
# Uttar Pradesh        1
# Uttaranchal          1
# West Bengal          1
# Name: states, dtype: int64

# %%
ecom.level.value_counts().sort_index()
# Out:
# high    20
# low     16
# Name: level, dtype: int64

# %%
sns.countplot(ecom.level)
plt.title("Literacy rate level indicator")
plt.show()

# %%
# 2.) How many states have high literacy rates level .
ecom[ecom.level=="high"].states.value_counts()
# Out:
# Manipur              1
# Himachal Pradesh     1
# Chandigarh           1
# Gujarat              1
# Uttaranchal          1
# Mizoram              1
# Goa                  1
# Delhi                1
# Nagaland             1
# Kerala               1
# Puducherry           1
# A. and N. Islands    1
# Daman and Diu        1
# Maharashtra          1
# Sikkim               1
# Lakshadweep          1
# Tamil Nadu           1
# Punjab               1
# Tripura              1
# West Bengal          1
# Name: states, dtype: int64

# %%
3.) How many states have low litracy levels.
ecom[ecom.level=="low"].states.value_counts()
# Out:
# Uttar Pradesh        1
# Chhatisgarh          1
# Jammu and Kashmir    1
# Haryana              1
# Jharkhand            1
# Karnataka            1
# All India            1
# Rajasthan            1
# Madhya Pradesh       1
# Bihar                1
# D. and N. Haveli     1
# Andhra Pradesh       1
# Assam                1
# Meghalaya            1
# Arunachal Pradesh    1
# Odisha               1
# Name: states, dtype: int64

# %%
plt.figure(figsize=(15,25))
sns.countplot(ecom.level,hue=ecom.states)
axes.plot(label='states')
axes.set_title("Literacy rate level indicator of all states")
axes.legend(loc=2)

#there has been an non-even literacy rate distribution.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1055a8e0d14d> in <module>
#       1 plt.figure(figsize=(15,25))
#       2 sns.countplot(ecom.level,hue=ecom.states)
# ----> 3 axes.plot(label='states')
#       4 axes.set_title("Literacy rate level indicator of all states")
#       5 axes.legend(loc=2)
#
# NameError: name 'axes' is not defined

# %% [markdown]
# # 4.)count the number of highest repeated literacy rate % of male and female present in 1991,2001 and 2011?
# ecom['Male_ninetyone'].value_counts()
# #i.e is 41%

# %%
ecom['Female_ninetyone'].value_counts()
#i.e 55%
# Out:
# 55    3
# 66    2
# 68    2
# 73    2
# 84    2
# 82    2
# 63    1
# 79    1
# 0     1
# 67    1
# 69    1
# 71    1
# 72    1
# 74    1
# 75    1
# 77    1
# 83    1
# 62    1
# 86    1
# 90    1
# 94    1
# 51    1
# 52    1
# 53    1
# 54    1
# 56    1
# 58    1
# 59    1
# 64    1
# Name: Female_ninetyone, dtype: int64

# %%
ecom['Male_zeroone'].value_counts()
#i.e 63,69 and 82%
# Out:
# 63    3
# 69    3
# 82    3
# 65    2
# 67    2
# 56    2
# 54    2
# 81    2
# 77    2
# 73    1
# 68    1
# 70    1
# 71    1
# 72    1
# 78    1
# 74    1
# 61    1
# 87    1
# 89    1
# 91    1
# 47    1
# 58    1
# 60    1
# 64    1
# Name: Male_zeroone, dtype: int64

# %%
ecom['Female_zeroone'].value_counts()
i.e 76%
# Out:
# 76    4
# 86    3
# 71    3
# 75    3
# 67    2
# 87    2
# 77    2
# 80    2
# 60    1
# 79    1
# 65    1
# 69    1
# 70    1
# 81    1
# 94    1
# 82    1
# 83    1
# 85    1
# 88    1
# 89    1
# 91    1
# 93    1
# 64    1
# Name: Female_zeroone, dtype: int64

# %%
ecom['RuralMale_twentyeleven'].value_counts()
# Out:
# 89    4
# 76    3
# 77    3
# 82    3
# 95    2
# 85    2
# 75    2
# 79    2
# 87    2
# 83    1
# 86    1
# 80    1
# 92    1
# 78    1
# 88    1
# 90    1
# 74    1
# 73    1
# 72    1
# 70    1
# 69    1
# 67    1
# Name: RuralMale_twentyeleven, dtype: int64

# %%
ecom['RuralFemale_twentyeleven'].value_counts()
# Out:
# 52    4
# 80    3
# 66    3
# 72    3
# 73    3
# 60    2
# 69    2
# 49    2
# 61    2
# 63    1
# 68    1
# 75    1
# 91    1
# 82    1
# 89    1
# 46    1
# 50    1
# 54    1
# 55    1
# 58    1
# 65    1
# Name: RuralFemale_twentyeleven, dtype: int64

# %%
ecom['UrbanMale_twentyeleven'].value_counts()
#i.e  92%
# Out:
# 92    7
# 93    5
# 91    4
# 89    4
# 88    4
# 96    2
# 90    2
# 98    1
# 97    1
# 94    1
# 87    1
# 86    1
# 84    1
# 83    1
# 80    1
# Name: UrbanMale_twentyeleven, dtype: int64

# %%
ecom['UrbanFemale_twentyeleven'].value_counts()
#i.e 81%
# Out:
# 81    5
# 79    4
# 77    4
# 87    3
# 85    3
# 69    2
# 71    2
# 88    2
# 83    2
# 74    1
# 76    1
# 97    1
# 80    1
# 93    1
# 84    1
# 89    1
# 91    1
# 82    1
# Name: UrbanFemale_twentyeleven, dtype: int64

# %%
# 5.)show and plot the average literacy rate of atleast 5 states?
ecom[ecom.states=='All India'].Average_litrate.value_counts()
# Out:
# 67.0    1
# Name: Average_litrate, dtype: int64

# %%
ecom[ecom.states=='Daman and Diu'].Average_litrate.value_counts()
# Out:
# 79.25    1
# Name: Average_litrate, dtype: int64

# %%
ecom[ecom.states=='Delhi'].Average_litrate.value_counts()
# Out:
# 80.833333    1
# Name: Average_litrate, dtype: int64

# %%
ecom[ecom.states=='Bihar'].Average_litrate.value_counts()
# Out:
# 55.083333    1
# Name: Average_litrate, dtype: int64

# %%
ecom[ecom.states=='Assam'].Average_litrate.value_counts()
# Out:
# 68.333333    1
# Name: Average_litrate, dtype: int64

# %%
plt.figure(figsize=(100,40))
sns.countplot(ecom.Average_litrate,hue=ecom.states)
plt.title("Literacy rate level indicator of all states")
plt.show()
plt.xticks(rotation=100)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text xticklabel objects>)

# %%
#6.) plot a five number summary for three parameters - literacy rate of urban  and rural Person in year 2011 and average literacy rates.
ecom["Average_litrate"].min()
ecom["Average_litrate"].max()
ecom["UrbanPersons_twentyeleven"].min()
ecom["UrbanPersons_twentyeleven"].max()
ecom["RuralPerson_twentyeleven"].min()
ecom["RuralPerson_twentyeleven"].max()

ecom["Average_litrate"].std()
ecom["UrbanPersons_twentyeleven"].std()
ecom["RuralPerson_twentyeleven"].std()

ecom["Average_litrate"].mean()
ecom["Average_litrate"].median()

ecom["UrbanPersons_twentyeleven"].mean()
ecom["UrbanPersons_twentyeleven"].median()

ecom["RuralPerson_twentyeleven"].mean()
ecom["RuralPerson_twentyeleven"].median()
# Out:
# 72.0

# %%
plt.figure(figsize=(10,5))
sns.set(style='whitegrid')
sns.boxplot(ecom['Average_litrate'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set(style='whitegrid')
sns.boxplot(ecom['UrbanPersons_twentyeleven'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set(style='whitegrid')
sns.boxplot(ecom['RuralPerson_twentyeleven'])
plt.show()

# %%
#8.) Plot a line graph for statistics of data?
ecom.describe().plot(kind = "Area",fontsize=15, figsize = (20,10), table = True,colormap="rainbow")
plt.xlabel('Statistics',)
plt.ylabel('Value')
plt.title("General Statistics")
# Out:
# Text(0.5, 1.0, 'General Statistics')

# %%
#9.) Draw two graphs on same canvas for generation parameter. First graph should be Pie Chart and Second graph should be Count plot.
f,ax=plt.subplots(1,2,figsize=(18,8))
ecom['level'].value_counts().plot.pie(explode=[0.1,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('level Count')
ax[0].set_ylabel('Count')
sns.countplot(ecom.level)
ax[1].set_title('level Count')
plt.show()

# %%
#10.) Visualize co-relation btw data?
sns.heatmap(ecom.corr(),cmap='YlGnBu',annot=True)
plt.show()

# %%
#11.)Plot graph between each unique values of level parameter. Also use violinplot between level and literacy rates of persons of year 2001.
sns.pairplot(ecom,hue='level')
plt.show()

# %%
import seaborn as sns
sns.violinplot(x=ecom['level'],y=ecom['Persons_zeroone'])
plt.show()

# %%
#12.)Plot a joint plot between -
i) UrbanPersons_twentyeleven on y-axis  and RuralPerson_twentyeleven on  (scatter plot).
ii)Male_ninetyone  on x-axis and Female_ninetyone 	 on y-axis (reg plot) .

# %%
fig=sns.jointplot(y='UrbanPersons_twentyeleven',x='RuralPerson_twentyeleven',data=ecom)
plt.show()

# %%
# Show the joint distribution using kernel density estimation
g = sns.jointplot(ecom.Male_ninetyone,ecom['Female_ninetyone'], kind="hex", height=7, space=0)
plt.show()

# %%
#13.)Create a new column named totalmean that contains the totalmean of the average column?
ecom['totalmean'] = ecom.Average_litrate
ecom.totalmean.mean()
# Out:
# 71.40740740740742
